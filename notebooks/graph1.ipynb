# %% [markdown]
# # Save graphs as image files (png/jpg) from the documents

# %%
#pip install Pillow
import minecart

pdf_file = open('SR.19.01696_Generic Materials Selection Guide for Amine Treating Units.pdf', 'rb')

doc = minecart.Document(pdf_file)
page = doc.get_pages(0)

im = page.images[0].as_pil()
im.show()

#im.save('test1.jpeg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-a0d2dc9d126d> in <module>
#       4 pdf_file = open('SR.19.01696_Generic Materials Selection Guide for Amine Treating Units.pdf', 'rb')
#       5
# ----> 6 doc = minecart.Document(pdf_file)
#       7 page = doc.get_pages(0)
#       8
#
# ~\Anaconda3\lib\site-packages\minecart\miner.py in __init__(self, pdffile)
#     328         self.interpreter = ColoredInterpreter(res_mgr, self.device)
#     329         self.parser = pdfminer.pdfparser.PDFParser(pdffile)
# --> 330         self.doc = pdfminer.pdfparser.PDFDocument(caching=True)
#     331         self.parser.set_document(self.doc)
#     332         self.doc.set_parser(self.parser)
#
# AttributeError: module 'pdfminer.pdfparser' has no attribute 'PDFDocument'

# %%
"""
# %matplotlib inline

from PIL import Image
from scipy import *
from pylab import *

im = array(Image.open('C:/Users/Ranja.Sarkar/Desktop/test1.jpeg'))
#print(type(im), im.shape, im.dtype)
#imshow(im) 

vr = im.shape[0]
hr = im.shape[1]

yr = linspace(0.5, 2e-4, vr)
xr = linspace(1, 14, hr)

for i in range(vr):
    for j in range(hr):
        im[i,j,:] = 

#print(len(xr), len(ys))
#print(xr.round(2), ys.round(2))

"""

# %% [markdown]
# # Use cv2 library to show or resize image

# %%
"""
# %matplotlib notebook 

import cv2
import matplotlib.pyplot as plt

image = cv2.imread('C:/Users/test1.jpeg')
resized_image = cv2.resize(image, (250, 400))
plt.imshow(resized_image)


##ax = plt.gca()

##vr = resized_image.shape[0]
##hr = resized_image.shape[1]

#yr = linspace(6, 11)
#xr = linspace(0, 200, dtype = int)

##print(yr.round(2), xr)

##RGB values of the image
#print(im[:,:,:])

##len(im[:,:,:])
##im[0,0,0]

#print(resized_image.shape)

##abs(im[:,:,0]/255-1).astype(bool)
#len(abs(im[:,:,0]/255).astype(bool))

"""

"""
#python imaging library
from PIL import Image
from pylab import *

im = array(Image.open('C:/Users/Ranja.Sarkar/test1.jpeg'))
#imshow(im)
#axis('off')

##RGB image linearly calibrated according to ITU-R 709, using the D65 luminant) to the CIE XYZ color space

rgb2xyz = (0.412453, 0.357580, 0.180423, 0,
    0.212671, 0.715160, 0.072169, 0,
    0.019334, 0.119193, 0.950227, 0 )

img = Image.open('C:/Users/Ranja.Sarkar/test1.jpeg', 'r')
out = img.convert("RGB", rgb2xyz)

#out

"""

# %% [markdown]
# # Interactive plot of the image

# %%
#Image.fromarray(im)
#Image.fromarray(uint8(im))

"""
img = Image.open('C:/Users/Ranja.Sarkar/test1.jpeg', 'r')

pix_val = list(img.getdata())

len(pix_val)

#pix_val_flat = [x for sets in pix_val for x in sets]
#len(pix_val_flat)

vr = im.shape[0]
hr = im.shape[1]
yr = linspace(6, 11, vr)
xr = linspace(0, 200, hr, dtype = int)

#for i in range(vr):
#    for j in range(hr):
#        print(hr, vr, im[i,j,:])

"""

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# %matplotlib inline
# img=mpimg.imread('C:/Users/Ranja.Sarkar/t.jpeg')
# plt.imshow(img)
# plt.show()

"""
import cv2
import numpy as np
import matplotlib.pyplot as plt
import imutils
img = cv2.imread("C:/Users/Ranja.Sarkar/test1.jpeg",0)
img1 = imutils.resize(img)
img2 = img1[0:471,0:750]  #roi of the image

indices = np.where(img2!= [0])
coordinates = zip(indices[0], indices[1])

indices
#coordinates

"""

# %%
vr = im.shape[0]
hr = im.shape[1]
print(im.shape)

col = array([255, 0, 0])

yax = linspace(6, 11 , vr)
#xax = linspace(0, 200, dtype = int)
xax = [14, 28, 56, 100, 120, 153, 188]
#xax = 24 * xax

for i in range(vr):
    for j in range(hr):
        im[i,j,:] = 255 * (any(im[i,j,:] > col) or any(im[i,j,:] < col))

        
#mapim = abs(im[:,:,0]/255).astype(bool)
mapim = (im[:,:,0]/255).astype(bool)

yval = array([average(yax[mapim[:,t]]) for t in range(0, hr, 100)])

#print(xax, yval.round(2))

#print(im.shape, vr, hr, len(xax), len(yval))

# (471, 750, 3) 471 750 750 750

# %%
# %matplotlib notebook

from PIL import Image
from scipy import *
from pylab import *

im = array(Image.open('C:/Users/Ranja.Sarkar/test1.jpeg'))
vr = im.shape[0]
hr = im.shape[1]
#print(vr, hr) #471, 750
imshow(im)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
xp = [14, 28, 56, 100, 120, 153, 188]
#xp = 24 * xp
#for i in range(0, 7):
#    xp1 = (xp[i]/200) * 750
#    print(round(xp1,2))

vr, hr = im.shape[0], im.shape[1]

yp1 = [318, 311, 268, 234, 321, 323, 323]
yp11 = []
yp2 = [287, 269, 213, 204, 280, 230, 260]
yp22 = []

#From nb hoverarrow CI
for i in range(0, 7):
    yps1 = ((1 - yp1[i]/vr) * 5) + 5.5 #adjust the offset
    yp11.append(round(yps1, 1))

#From nb hoverarrow KHI
for i in range(0, 7):
    yps2 = ((1 - yp2[i]/vr) * 5) + 5.5  #adjust the offset
    yp22.append(round(yps2, 1))
    
xp, yp11, yp22
# Out:
# ([14, 28, 56, 100, 120, 153, 188],
#  [7.1, 7.2, 7.7, 8.0, 7.1, 7.1, 7.1],
#  [7.5, 7.6, 8.2, 8.3, 7.5, 8.1, 7.7])

# %%
#%matplotlib inline

#plot(yp11), plot(yp22)

# %%
import pandas as pd

df1 = pd.DataFrame(columns = ['DP ID', 'Trade name', 'Polymer', 'Exposure medium','Concentration (vol%)', 'Temperature (Celsius)', 'Duration (h)', 'Weight change (%)', 'Density change (%)', 'Volume change (%)', 'Qualitative test results'])

for i in range(0, 7):
    df1 = df1.append({'DP ID': '03', 'Trade name':'Coflon', 'Polymer':'PVDF', 'Exposure medium':'CI SURFO PLUS','Concentration (vol%)':'100', 'Temperature (Celsius)':'55','Duration (h)': xr[i], 'Volume change (%)':yval[i],'Weight change (%)':'', 'Density change (%)':'','Qualitative test results':''}, ignore_index = True)


#df1

df2 = pd.DataFrame(columns = ['DP ID', 'Trade name', 'Polymer', 'Exposure medium','Concentration (vol%)', 'Temperature (Celsius)', 'Duration (h)', 'Weight change (%)', 'Density change (%)', 'Volume change (%)', 'Qualitative test results'])

for i in range(0, 7):
    df2 = df2.append({'DP ID': '03', 'Trade name':'Coflon', 'Polymer':'PVDF', 'Exposure medium':'KHI','Concentration (vol%)':'100', 'Temperature (Celsius)':'55','Duration (h)': xr[i], 'Volume change (%)':yval[i],'Weight change (%)':'', 'Density change (%)':'','Qualitative test results':''}, ignore_index = True)


#df2
