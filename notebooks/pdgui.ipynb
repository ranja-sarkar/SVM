# %% [markdown]
# # GUI

# %%
import pandas as pd
from pandasgui import show

# %%
df1 = pd.read_excel('DP_quant.xlsx')
#show(df)
show(df1, settings = {'block': True})

# %%
df2 = pd.read_excel('DP_qual.xlsx')
show(df2, settings = {'block': True})

# %% [markdown]
# # MISSING DATA

# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_excel('DP_quant.xlsx')

# %%
#data completeness or density
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
#nullity by column
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
#nullity correlation
#correlation heatmap: how strongly the presence/absence of 1 variable affects the presence of another
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Nullity correlation ranges from -1 (if one variable appears the other definitely does not) to 0 (variables appearing or not appearing have no effect on one another)
# to 1 (if one variable appears the other definitely also does). Entries marked <1 or >-1 have a correlation that is close to being exactingly negative or positive,
# but is still not quite perfectly so.

# %%
#hierarchical clustering algo (how much you would have to fill in or drop)

msno.dendrogram(df)
# Out:
# <AxesSubplot:>

# %%
df= pd.read_csv('BJSA.csv', low_memory = False)
show(df, settings = {'block': True})
# Out:
# PandasGUI ERROR — pandasgui.widgets.grapher — Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['date', 'index', 'BS:PI-0011-030-B__PV_RW', 'BS:PI-0011-031-A__PV_RW', 'BS:PI-0012-030-A__PV_RW', 'BS:PI-0012-030-B__PV_RW', 'BS:PI-0012-031-A__PV_RW', 'BS:PI-0012-031-B__PV_RW', 'BS:PI-0012-032-A__PV_RW', 'BS:PI-0012-032-B__PV_RW', 'BS:PI-0012-050-A__PV_RW', 'BS:PI-0012-050-B__PV_RW', 'BS:PI-0012-060-A__PV_RW', 'BS:PI-0012-060-B__PV_RW', 'BS:PI-0013-031-A__PV_RW', 'BS:PI-0014-030-B__PV_RW', 'BS:PI-0014-031-A__PV_RW', 'BS:PI-0015-030-A__PV_RW', 'BS:PI-0015-030-B__PV_RW', 'BS:PI-0015-031-A__PV_RW', 'BS:PI-0015-031-B__PV_RW', 'BS:PI-0015-032-A__PV_RW', 'BS:PI-0015-032-B__PV_RW', 'BS:PI-0015-060-A__PV_RW', 'BS:PI-0015-060-B__PV_RW', 'BS:PI-0016-030-A__PV_RW', 'BS:PI-0016-030-B__PV_RW', 'BS:PI-0016-031-A__PV_RW', 'BS:PI-0016-031-B__PV_RW', 'BS:PI-0016-032-A__PV_RW', 'BS:PI-0016-032-B__PV_RW', 'BS:PI-0016-050-A__PV_RW', 'BS:PI-0016-050-B__PV_RW', 'BS:PI-0016-060-A__PV_RW', 'BS:PI-0016-060-B__PV_RW', 'BS:PI-0017-030-A__PV_RW', 'BS:PI-0017-030-B__PV_RW', 'BS:PI-0017-031-A__PV_RW', 'BS:PI-0017-031-B__PV_RW', 'BS:PI-0017-050-A__PV_RW', 'BS:PI-0017-050-B__PV_RW', 'BS:PI-0017-060-A__PV_RW', 'BS:PI-0017-060-B__PV_RW', 'BS:PI-0018-030-A__PV_RW', 'BS:PI-0018-030-B__PV_RW', 'BS:PI-0018-031-A__PV_RW', 'BS:PI-0018-031-B__PV_RW', 'BS:PI-0018-050-A__PV_RW', 'BS:PI-0018-050-B__PV_RW', 'BS:PI-0018-060-A__PV_RW', 'BS:PI-0018-060-B__PV_RW', 'BS:PI-0019-030-A__PV_RW', 'BS:PI-0019-030-B__PV_RW', 'BS:PI-0019-031-A__PV_RW', 'BS:PI-0019-031-B__PV_RW', 'BS:PI-0019-032-A__PV_RW', 'BS:PI-0019-032-B__PV_RW', 'BS:PI-0019-050-A__PV_RW', 'BS:PI-0019-050-B__PV_RW', 'BS:PI-0019-060-A__PV_RW', 'BS:PI-0020-030-B__PV_RW', 'BS:PI-0020-031-A__PV_RW', 'BS:PI-0020-031-B__PV_RW', 'BS:PI-0020-050-A__PV_RW', 'BS:PI-0020-050-B__PV_RW', 'BS:PI-0020-060-A__PV_RW', 'BS:PI-0020-060-B__PV_RW', 'BS:PI-0021-030-A__PV_RW', 'BS:PI-0021-030-B__PV_RW', 'BS:PI-0021-031-A__PV_RW', 'BS:PI-0021-031-B__PV_RW', 'BS:PI-0021-032-A__PV_RW', 'BS:PI-0021-050-A__PV_RW', 'BS:PI-0021-050-B__PV_RW', 'BS:PI-0021-060-A__PV_RW', 'BS:PI-0021-060-B__PV_RW', 'BS:PI-0022-030-A__PV_RW', 'BS:PI-0022-030-B__PV_RW', 'BS:PI-0022-031-A__PV_RW', 'BS:PI-0022-031-B__PV_RW', 'BS:PI-0022-050-A__PV_RW', 'BS:PI-0022-050-B__PV_RW', 'BS:PI-0022-060-A__PV_RW', 'BS:PI-0022-060-B__PV_RW', 'BS:PI-0441-901____PV_RW', 'BS:PI-0442-101____PV_RW', 'BS:PI-0442-102____PV_RW', 'BS:PI-0442-201____PV_RW', 'BS:PI-0442-301____PV_RW', 'BS:PI-0442-401____PV_RW', 'BS:PI-0442-701____PV_RW', 'BS:PI-0442-801____PV_RW'] but received: BS:PIC-3610-1________PV
# PandasGUI ERROR — pandasgui.widgets.grapher — All arguments should have the same length. The length of argument `y` is 3, whereas the length of  previously-processed arguments ['date'] is 52129
# PandasGUI ERROR — pandasgui.store — False
# Traceback (most recent call last):
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2646, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas\_libs\index.pyx", line 111, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 135, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index_class_helper.pxi", line 109, in pandas._libs.index.Int64Engine._check_type
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandasgui\store.py", line 199, in apply_filters
#     df = df.query(filt.expr)
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3234, in query
#     new_data = self.loc[res]
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\indexing.py", line 1767, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\indexing.py", line 1964, in _getitem_axis
#     return self._get_label(key, axis=axis)
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\indexing.py", line 624, in _get_label
#     return self.obj._xs(label, axis=axis)
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\generic.py", line 3537, in xs
#     loc = self.index.get_loc(key)
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\indexes\range.py", line 353, in get_loc
#     return super().get_loc(key, method=method, tolerance=tolerance)
#   File "C:\Users\Ranja.Sarkar\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2648, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas\_libs\index.pyx", line 111, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 135, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index_class_helper.pxi", line 109, in pandas._libs.index.Int64Engine._check_type
# KeyError: False
