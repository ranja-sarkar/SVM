# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # Call database/create connection

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except:
        print('This database does not exist')

    return conn

# %%
conn = create_connection('Polymer_Database.db')
cur = conn.cursor()

cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
print(cur.fetchall())

#table = pd.read_sql_query("SELECT * from table_name", conn)
#table.to_csv(table_name + '.csv', index_label = 'index')
# Out:
# [('DP_qual',), ('DP_quant',), ('DP_CCS',), ('ext',), ('ext_other chemicals',), ('int+ext',), ('01_CCS',), ('0203_CCS',), ('0405_CCS',), ('06_CCS',), ('08_CCS',), ('09_CCS',)]

# %%
def select_task(conn, query):
    """
    Query all rows in the table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute(query)

    rows = cur.fetchall()
    for row in rows:
        #print(row)
        df = pd.read_sql(query, conn)
        return df

# %%
query = "SELECT * FROM DP_quant where Polymer = 'HNBR' and [Trade name] = 'HNBR'"
#print(row)
select_task(conn, query)
# Out:
#     DP ID Trade name Category of non-metallic materials Polymer  \
# 0       1       HNBR                          Elastomer    HNBR
# 1       1       HNBR                          Elastomer    HNBR
# 2       1       HNBR                          Elastomer    HNBR
# 3       1       HNBR                          Elastomer    HNBR
# 4       1       HNBR                          Elastomer    HNBR
# ..    ...        ...                                ...     ...
# 61      4       HNBR                          Elastomer    HNBR
# 62      4       HNBR                          Elastomer    HNBR
# 63      4       HNBR                          Elastomer    HNBR
# 64      4       HNBR                          Elastomer    HNBR
# 65      4       HNBR                          Elastomer    HNBR
#
#                   Exposure medium  Concentration of medium (vol%)  \
# 0                     Sarapar 147                             100
# ...
